# %%
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams.update({'font.size':20})

# %%
F=np.linspace(0.01,4,100)
I=np.array([50,100,200,500,1000])

# %%
plt.figure(figsize=(5,5))
for Ix in I:
    plt.plot(Ix/F**2, F, label=Ix)
plt.legend(prop={'size': 12})
plt.xlim([0,5e2])
plt.xlabel(r"$\Sigma$")
plt.ylabel("F")
plt.show()
